# %%
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
my_cols=['x_f','y_f','id']
with open ('../data/map_data.txt') as f:
    map_df = pd.read_table(f, sep='\t', header=None, names=my_cols, lineterminator='\n')

# %%
plt.figure()
map_df.plot(kind='scatter', x='x_f', y='y_f')

# %%
map_df
# Out:
#          x_f        y_f  id
# 0    92.0640 -34.777000   1
# 1    61.1090 -47.132000   2
# 2    17.4200  -4.599300   3
# 3    -7.1285 -34.540000   4
# 4   232.3200  32.032000   5
# 5   177.4300  28.083000   6
# 6   286.8900  18.159000   7
# 7   274.3700  31.197000   8
# 8    47.4840 -36.786000   9
# 9    69.2000 -78.217000  10
# 10  124.6100  24.277000  11
# 11   36.2030  14.827000  12
# 12  -39.7860 -12.615000  13
# 13  -38.0250 -99.976000  14
# 14  267.3300 -14.272000  15
# 15   28.8980 -39.754000  16
# 16  -29.8360 -23.277000  17
# 17  255.6700   9.813700  18
# 18   13.4520 -72.827000  19
# 19  102.0400   5.177700  20
# 20   62.8380   1.905700  21
# 21  -14.9470 -61.919000  22
# 22   15.1620 -97.037000  23
# 23   36.6260 -28.898000  24
# 24  172.1600 -15.217000  25
# 25  136.9500 -14.130000  26
# 26  -41.7140 -61.328000  27
# 27   39.5560 -47.361000  28
# 28  195.6500   8.667700  29
# 29  278.0000  13.181000  30
# 30  151.0300   8.912700  31
# 31    8.7638   7.564700  32
# 32   83.0060  20.959000  33
# 33  205.3900  29.686000  34
# 34  264.5100  24.454000  35
# 35  214.5400  -7.871100  36
# 36   53.2700 -55.233000  37
# 37   20.1390 -20.150000  38
# 38    8.2018 -20.970000  39
# 39  -13.6410  -0.098341  40
# 40  278.9200  21.918000  41
# 41  170.6200  28.733000  42
